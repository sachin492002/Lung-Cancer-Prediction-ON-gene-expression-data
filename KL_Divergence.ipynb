# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import entropy

# %%
# KL Divergence for each feature
def kl_divergence(feature_name, dataset):
    neg_feature_data = dataset[dataset['label'] == 0][feature_name] # 负样本数据
    pos_feature_data = dataset[dataset['label'] == 1][feature_name] # 正样本数据

    min_value = min(neg_feature_data.min(), pos_feature_data.min())
    max_value = max(neg_feature_data.max(), pos_feature_data.max())
    # min_value = pos_feature_data.min() if neg_feature_data.min() > pos_feature_data.min() else neg_feature_data.min()
    # max_value = neg_feature_data.max() if neg_feature_data.max() > pos_feature_data.max() else pos_feature_data.max()
    # c = 0
    # if(c==0):
    #     plt.hist(neg_feature_data, bins = 10, range=(min_value, max_value), density = True, alpha = 0.5, label = 'neg', color = 'red')
    #     plt.hist(pos_feature_data, bins = 10, range=(min_value, max_value), density = True, alpha = 0.5, label = 'pos', color = 'blue')
    #     plt.legend()
    #     plt.show()
    #     c = 1
    neg_hist, neg_bin = np.histogram(neg_feature_data, bins = 10, range=(min_value, max_value), density = True)
    pos_hist, pos_bin = np.histogram(pos_feature_data, bins = 10, range=(min_value, max_value), density = True)
    pos_hist[pos_hist == 0] = 1e-7
    neg_hist[neg_hist == 0] = 1e-7
    return entropy(neg_hist, pos_hist, base = 2)

# %%
def get_all_kl_divergence(df):
    features =[]
    feature_kl = []
    size = len(df.columns)
    i = 0
    # print(df[df.columns[19944]])
    for feature in df.columns: 
        if feature == 'label' or feature == 'file_id':
            continue
        features.append(feature)
        feature_kl.append(kl_divergence(feature, df))
        i = i + 1
        print('process:{} / {}'.format(i, feature))
    kl_feature_dataset = pd.DataFrame()
    kl_feature_dataset['feature_name'] = features
    kl_feature_dataset['kl_divergence'] = feature_kl
    final = kl_feature_dataset.sort_values('kl_divergence', ascending=False)
    return final

# %%
# Read the preprocessed data and calculate the KL divergence for each feature
df = pd.read_csv('TCGA_Labeled_Selected_GOA.csv', index_col = 0)
dd = get_all_kl_divergence(df)
choosed_features = dd[dd['kl_divergence'] > 3].reset_index(drop = True)
choosed_features
# Out:
# process:1 / OR4F29
# process:2 / OR4F16
# process:3 / SAMD11
# process:4 / NOC2L
# process:5 / KLHL17
# process:6 / PERM1
# process:7 / HES4
# process:8 / ISG15
# process:9 / RNF223
# process:10 / C1orf159
# process:11 / TTLL10
# process:12 / TNFRSF18
# process:13 / PUSL1
# process:14 / INTS11
# process:15 / TAS1R3
# process:16 / DVL1
# process:17 / MRPL20
# process:18 / ANKRD65
# process:19 / VWA1
# process:20 / ATAD3B
# process:21 / ATAD3A
# process:22 / TMEM240
# process:23 / FNDC10
# process:24 / MIB2
# process:25 / MMP23B
# process:26 / CDK11B
# process:27 / SLC35E2B
# process:28 / CDK11A
# process:29 / CALML6
# process:30 / GABRD
# process:31 / PRKCZ
# process:32 / FAAP20
# process:33 / SKI
# process:34 / RER1
# process:35 / PLCH2
# process:36 / PANK4
# process:37 / HES5
# process:38 / PRXL2B
# process:39 / TTC34
# process:40 / ARHGEF16
# process:41 / MEGF6
# process:42 / TPRG1L
# process:43 / WRAP73
# process:44 / DFFB
# process:45 / AJAP1
# process:46 / NPHP4
# process:47 / RPL22
# process:48 / RNF207
# process:49 / ICMT
# process:50 / HES3
# process:51 / GPR153
# process:52 / TNFRSF25
# process:53 / KLHL21
# process:54 / THAP3
# process:55 / CAMTA1
# process:56 / PER3
# process:57 / UTS2
# process:58 / TNFRSF9
# process:59 / ERRFI1
# process:60 / SLC45A1
# process:61 / RERE
# process:62 / ENO1
# process:63 / CA6
# process:64 / SLC2A7
# process:65 / SLC2A5
# process:66 / GPR157
# process:67 / H6PD
# process:68 / SLC25A33
# process:69 / PIK3CD
# process:70 / CLSTN1
# process:71 / CTNNBIP1
# process:72 / LZIC
# process:73 / NMNAT1
# process:74 / RBP7
# process:75 / UBE4B
# process:76 / KIF1B
# process:77 / PGD
# process:78 / CENPS-CORT
# process:79 / CORT
# process:80 / DFFA
# process:81 / CASZ1
# process:82 / C1orf127
# process:83 / TARDBP
# process:84 / SRM
# process:85 / ANGPTL7
# process:86 / UBIAD1
# process:87 / FBXO2
# process:88 / FBXO44
# process:89 / FBXO6
# process:90 / MAD2L2
# process:91 / DRAXIN
# process:92 / AGTRAP
# process:93 / C1orf167
# process:94 / MTHFR
# process:95 / CLCN6
# process:96 / NPPA
# process:97 / KIAA2013
# process:98 / MFN2
# process:99 / MIIP
# process:100 / TNFRSF8
# process:101 / TNFRSF1B
# process:102 / VPS13D
# process:103 / AADACL4
# process:104 / PRAMEF12
# process:105 / PRAMEF11
# process:106 / PRAMEF2
# process:107 / PRAMEF4
# process:108 / PRAMEF10
# process:109 / PRAMEF6
# process:110 / PRAMEF27
# process:111 / HNRNPCL4
# process:112 / PRAMEF9
# process:113 / PRAMEF8
# process:114 / PRAMEF33
# process:115 / PRAMEF14
# process:116 / PRAMEF17
# process:117 / LRRC38
# process:118 / PDPN
# process:119 / PRDM2
# process:120 / EFHD2
# process:121 / CTRC
# process:122 / CELA2A
# process:123 / AGMAT
# process:124 / PLEKHM2
# process:125 / SLC25A34
# process:126 / TMEM82
# process:127 / FBLIM1
# process:128 / UQCRHL
# process:129 / SPEN
# process:130 / ZBTB17
# process:131 / SRARP
# process:132 / HSPB7
# process:133 / CLCNKA
# process:134 / CLCNKB
# process:135 / FAM131C
# process:136 / CPLANE2
# process:137 / FBXO42
# process:138 / SZRD1
# process:139 / SPATA21
# process:140 / NBPF1
# process:141 / CROCC
# process:142 / ATP13A2
# process:143 / PADI3
# process:144 / RCC2
# process:145 / ACTL8
# process:146 / IGSF21
# process:147 / PAX7
# process:148 / ALDH4A1
# process:149 / IFFO2
# process:150 / EMC1
# process:151 / AKR7A2
# process:152 / CAPZB
# process:153 / MICOS10
# process:154 / NBL1
# process:155 / MICOS10-NBL1
# process:156 / HTR6
# process:157 / RNF186
# process:158 / OTUD3
# process:159 / PLA2G2A
# process:160 / PLA2G2C
# process:161 / UBXN10
# process:162 / MUL1
# process:163 / CDA
# process:164 / PINK1
# process:165 / DDOST
# process:166 / KIF17
# process:167 / SH2D5
# process:168 / EIF4G3
# process:169 / ECE1
# process:170 / NBPF3
# process:171 / ALPL
# process:172 / USP48
# process:173 / LDLRAD2
# process:174 / HSPG2
# process:175 / CELA3B
# process:176 / CELA3A
# process:177 / CDC42
# process:178 / WNT4
# process:179 / ZBTB40
# process:180 / EPHA8
# process:181 / C1QA
# process:182 / C1QC
# process:183 / C1QB
# process:184 / EPHB2
# process:185 / KDM1A
# process:186 / LUZP1
# process:187 / HTR1D
# process:188 / HNRNPR
# process:189 / TCEA3
# process:190 / ASAP3
# process:191 / E2F2
# process:192 / ID3
# process:193 / RPL11
# process:194 / HMGCL
# process:195 / FUCA1
# process:196 / CNR2
# process:197 / IL22RA1
# process:198 / IFNLR1
# process:199 / GRHL3
# process:200 / STPG1
# process:201 / RCAN3
# process:202 / SRRM1
# process:203 / RHCE
# process:204 / MACO1
# process:205 / AUNIP
# process:206 / STMN1
# process:207 / PAFAH2
# process:208 / EXTL1
# process:209 / TRIM63
# process:210 / PDIK1L
# process:211 / FAM110D
# process:212 / C1orf232
# process:213 / AL391650.1
# process:214 / CNKSR1
# process:215 / CATSPER4
# process:216 / UBXN11
# process:217 / LIN28A
# process:218 / DHDDS
# process:219 / HMGN2
# process:220 / ARID1A
# process:221 / SFN
# process:222 / GPN2
# process:223 / GPATCH3
# process:224 / NUDC
# process:225 / KDF1
# process:226 / TENT5B
# process:227 / SLC9A1
# process:228 / WDTC1
# process:229 / TMEM222
# process:230 / SYTL1
# process:231 / MAP3K6
# process:232 / GPR3
# process:233 / AHDC1
# process:234 / FGR
# process:235 / IFI6
# process:236 / FAM76A
# process:237 / STX12
# process:238 / PPP1R8
# process:239 / XKR8
# process:240 / DNAJC8
# process:241 / SESN2
# process:242 / MED18
# process:243 / RCC1
# process:244 / TAF12
# process:245 / RAB42
# process:246 / YTHDF2
# process:247 / EPB41
# process:248 / SRSF4
# process:249 / MECR
# process:250 / PTPRU
# process:251 / MATN1
# process:252 / LAPTM5
# process:253 / SDC3
# process:254 / PUM1
# process:255 / NKAIN1
# process:256 / SNRNP40
# process:257 / ZCCHC17
# process:258 / FABP3
# process:259 / SERINC2
# process:260 / TINAGL1
# process:261 / HCRTR1
# process:262 / COL16A1
# process:263 / ADGRB2
# process:264 / SPOCD1
# process:265 / PTP4A2
# process:266 / KHDRBS1
# process:267 / TMEM39B
# process:268 / KPNA6
# process:269 / TXLNA
# process:270 / CCDC28B
# process:271 / DCDC2B
# process:272 / TMEM234
# process:273 / EIF3I
# process:274 / FAM167B
# process:275 / LCK
# process:276 / HDAC1
# process:277 / MARCKSL1
# process:278 / TSSK3
# process:279 / FAM229A
# process:280 / ZBTB8A
# process:281 / ZBTB8OS
# process:282 / SYNC
# process:283 / KIAA1522
# process:284 / FNDC5
# process:285 / HPCA
# process:286 / RNF19B
# process:287 / AZIN2
# process:288 / TRIM62
# process:289 / A3GALT2
# process:290 / PHC2
# process:291 / CSMD2
# process:292 / HMGB4
# process:293 / C1orf94
# process:294 / GJB4
# process:295 / GJB3
# process:296 / GJA4
# process:297 / TMEM35B
# process:298 / ZMYM6
# process:299 / ZMYM4
# process:300 / NCDN
# process:301 / TFAP2E
# process:302 / C1orf216
# process:303 / CLSPN
# process:304 / AGO1
# process:305 / AGO3
# process:306 / ADPRS
# process:307 / TRAPPC3
# process:308 / MAP7D1
# process:309 / THRAP3
# process:310 / SH3D21
# process:311 / EVA1B
# process:312 / CSF3R
# process:313 / ZC3H12A
# process:314 / MEAF6
# process:315 / SNIP1
# process:316 / GNL2
# process:317 / RSPO1
# process:318 / C1orf109
# process:319 / CDCA8
# process:320 / EPHA10
# process:321 / YRDC
# process:322 / C1orf122
# process:323 / MTF1
# process:324 / SF3A3
# process:325 / FHL3
# process:326 / UTP11
# process:327 / POU3F1
# process:328 / GJA9
# process:329 / BMP8A
# process:330 / HPCAL4
# process:331 / PPIE
# process:332 / OXCT2
# process:333 / TRIT1
# process:334 / MYCL
# process:335 / MFSD2A
# process:336 / CAP1
# process:337 / PPT1
# process:338 / RLF
# process:339 / ZMPSTE24
# process:340 / SMAP2
# process:341 / EXO5
# process:342 / ZNF684
# process:343 / CITED4
# process:344 / CTPS1
# process:345 / SLFNL1
# process:346 / SCMH1
# process:347 / EDN2
# process:348 / HIVEP3
# process:349 / AC119676.1
# process:350 / GUCA2B
# process:351 / GUCA2A
# process:352 / FOXJ3
# process:353 / RIMKLA
# process:354 / CCDC30
# process:355 / PPIH
# process:356 / C1orf50
# process:357 / TMEM269
# process:358 / SVBP
# process:359 / ERMAP
# process:360 / SLC2A1
# process:361 / FAM183A
# process:362 / EBNA1BP2
# process:363 / TMEM125
# process:364 / TIE1
# process:365 / CDC20
# process:366 / ELOVL1
# process:367 / MED8
# process:368 / HYI
# process:369 / ST3GAL3
# process:370 / DPH2
# process:371 / ATP6V0B
# process:372 / SLC6A9
# process:373 / KLF17
# process:374 / ERI3
# process:375 / RNF220
# process:376 / TMEM53
# process:377 / ARMH1
# process:378 / KIF2C
# process:379 / RPS8
# process:380 / TCTEX1D4
# process:381 / PTCH2
# process:382 / HECTD3
# process:383 / UROD
# process:384 / HPDL
# process:385 / MUTYH
# process:386 / AL451136.1
# process:387 / MMACHC
# process:388 / PRDX1
# process:389 / NASP
# process:390 / GPBP1L1
# process:391 / IPP
# process:392 / MAST2
# process:393 / P3R3URF-PIK3R3
# process:394 / P3R3URF
# process:395 / LURAP1
# process:396 / RAD54L
# process:397 / NSUN4
# process:398 / DMBX1
# process:399 / KNCN
# process:400 / MOB3C
# process:401 / TEX38
# process:402 / EFCAB14
# process:403 / CYP4B1
# process:404 / CYP4A11
# process:405 / CYP4A22
# process:406 / TAL1
# process:407 / STIL
# process:408 / CMPK1
# process:409 / TRABD2B
# process:410 / SPATA6
# process:411 / BEND5
# process:412 / ELAVL4
# process:413 / FAF1
# process:414 / CDKN2C
# process:415 / RNF11
# process:416 / EPS15
# process:417 / OSBPL9
# process:418 / TXNDC12
# process:419 / AL445685.3
# process:420 / BTF3L4
# process:421 / ZFYVE9
# process:422 / CC2D1B
# process:423 / PRPF38A
# process:424 / TUT4
# process:425 / SHISAL2A
# process:426 / ZYG11B
# process:427 / SCP2
# process:428 / CPT2
# process:429 / CZIB
# process:430 / LRP8
# process:431 / DMRTB1
# process:432 / YIPF1
# process:433 / DIO1
# process:434 / LRRC42
# process:435 / TMEM59
# process:436 / TCEANC2
# process:437 / AL357673.1
# process:438 / CDCP2
# process:439 / CYB5RL
# process:440 / MRPL37
# process:441 / FAM151A
# process:442 / MROH7
# process:443 / TTC4
# process:444 / TTC22
# process:445 / LEXM
# process:446 / TMEM61
# process:447 / BSND
# process:448 / PCSK9
# process:449 / AC119674.2
# process:450 / PLPP3
# process:451 / PRKAA2
# process:452 / C8A
# process:453 / C8B
# process:454 / DAB1
# process:455 / TACSTD2
# process:456 / MYSM1
# process:457 / FGGY
# process:458 / CYP2J2
# process:459 / C1orf87
# process:460 / TM2D1
# process:461 / PATJ
# process:462 / KANK4
# process:463 / USP1
# process:464 / DOCK7
# process:465 / ATG4C
# process:466 / FOXD3
# process:467 / ALG6
# process:468 / ROR1
# process:469 / CACHD1
# process:470 / RAVER2
# process:471 / JAK1
# process:472 / AK4
# process:473 / DNAJC6
# process:474 / SGIP1
# process:475 / TCTEX1D1
# process:476 / DNAI4
# process:477 / MIER1
# process:478 / IL12RB2
# process:479 / SERBP1
# process:480 / GNG12
# process:481 / DIRAS3
# process:482 / DEPDC1
# process:483 / LRRC7
# process:484 / SRSF11
# process:485 / CTH
# process:486 / PTGER3
# process:487 / ZRANB2
# process:488 / NEGR1
# process:489 / LRRIQ3
# process:490 / FPGT
# process:491 / FPGT-TNNI3K
# process:492 / LRRC53
# process:493 / ERICH3
# process:494 / CRYZ
# process:495 / SLC44A5
# process:496 / ACADM
# process:497 / RABGGTB
# process:498 / MSH4
# process:499 / ST6GALNAC3
# process:500 / PIGK
# process:501 / AK5
# process:502 / MIGA1
# process:503 / NEXN
# process:504 / FUBP1
# process:505 / DNAJB4
# process:506 / GIPC2
# process:507 / PTGFR
# process:508 / IFI44
# process:509 / PRKACB
# process:510 / SAMD13
# process:511 / DNASE2B
# process:512 / CTBS
# process:513 / LPAR3
# process:514 / MCOLN2
# process:515 / DNAI3
# process:516 / C1orf52
# process:517 / CCN1
# process:518 / COL24A1
# process:519 / ODF2L
# process:520 / CLCA2
# process:521 / CLCA1
# process:522 / CLCA4
# process:523 / SH3GLB1
# process:524 / SELENOF
# process:525 / LMO4
# process:526 / PKN2
# process:527 / GTF2B
# process:528 / GBP4
# process:529 / GBP5
# process:530 / GBP6
# process:531 / LRRC8B
# process:532 / LRRC8C
# process:533 / LRRC8D
# process:534 / ZNF326
# process:535 / ZNF644
# process:536 / HFM1
# process:537 / CDC7
# process:538 / BRDT
# process:539 / EPHX4
# process:540 / BTBD8
# process:541 / C1orf146
# process:542 / RPAP2
# process:543 / GFI1
# process:544 / EVI5
# process:545 / RPL5
# process:546 / DIPK1A
# process:547 / MTF2
# process:548 / TMED5
# process:549 / CCDC18
# process:550 / FNBP1L
# process:551 / DNTTIP2
# process:552 / GCLM
# process:553 / ARHGAP29
# process:554 / ABCD3
# process:555 / ALG14
# process:556 / TLCD4
# process:557 / SNX7
# process:558 / PLPPR5
# process:559 / PLPPR4
# process:560 / PALMD
# process:561 / FRRS1
# process:562 / SLC35A3
# process:563 / AC118553.2
# process:564 / TRMT13
# process:565 / RTCA
# process:566 / GPR88
# process:567 / SLC30A7
# process:568 / S1PR1
# process:569 / AMY1C
# process:570 / PRMT6
# process:571 / NTNG1
# process:572 / VAV3
# process:573 / SLC25A24
# process:574 / NBPF4
# process:575 / FAM102B
# process:576 / AKNAD1
# process:577 / TAF13
# process:578 / C1orf194
# process:579 / CELSR2
# process:580 / PSRC1
# process:581 / MYBPHL
# process:582 / PSMA5
# process:583 / ATXN7L2
# process:584 / GPR61
# process:585 / GNAI3
# process:586 / GNAT2
# process:587 / AMPD2
# process:588 / GSTM4
# process:589 / GSTM2
# process:590 / GSTM1
# process:591 / GSTM5
# process:592 / GSTM3
# process:593 / CSF1
# process:594 / STRIP1
# process:595 / ALX3
# process:596 / UBL4B
# process:597 / SLC6A17
# process:598 / KCNC4
# process:599 / RBM15
# process:600 / LAMTOR5
# process:601 / KCNA10
# process:602 / KCNA2
# process:603 / KCNA3
# process:604 / CD53
# process:605 / DRAM2
# process:606 / DENND2D
# process:607 / OVGP1
# process:608 / WDR77
# process:609 / C1orf162
# process:610 / TMIGD3
# process:611 / ADORA3
# process:612 / INKA2
# process:613 / KCND3
# process:614 / CTTNBP2NL
# process:615 / WNT2B
# process:616 / RHOC
# process:617 / AL603832.3
# process:618 / TAFA3
# process:619 / SLC16A1
# process:620 / MAGI3
# process:621 / RSBN1
# process:622 / PTPN22
# process:623 / BCL2L15
# process:624 / AP4B1
# process:625 / DCLRE1B
# process:626 / SYT6
# process:627 / AMPD1
# process:628 / NRAS
# process:629 / CSDE1
# process:630 / SIKE1
# process:631 / TSHB
# process:632 / VANGL1
# process:633 / SLC22A15
# process:634 / CD58
# process:635 / IGSF3
# process:636 / CD2
# process:637 / PTGFRN
# process:638 / CD101
# process:639 / TTF2
# process:640 / TRIM45
# process:641 / MAN1A2
# process:642 / WDR3
# process:643 / TBX15
# process:644 / WARS2
# process:645 / HSD3B1
# process:646 / ZNF697
# process:647 / REG4
# process:648 / NOTCH2
# process:649 / NOTCH2NLR
# process:650 / NBPF26
# process:651 / PPIAL4A
# process:652 / FCGR1B
# process:653 / FAM72B
# process:654 / SRGAP2C
# process:655 / H3-2
# process:656 / FAM72C
# process:657 / NBPF15
# process:658 / FAM72D
# process:659 / NBPF20
# process:660 / GPR89A
# process:661 / CD160
# process:662 / RNF115
# process:663 / NUDT17
# process:664 / PIAS3
# process:665 / ANKRD35
# process:666 / RBM8A
# process:667 / AC243547.3
# process:668 / LIX1L
# process:669 / ANKRD34A
# process:670 / POLR3GL
# process:671 / HJV
# process:672 / NOTCH2NLA
# process:673 / PPIAL4H
# process:674 / NBPF12
# process:675 / PRKAB2
# process:676 / CHD1L
# process:677 / ACP6
# process:678 / GJA5
# process:679 / GJA8
# process:680 / PPIAL4G
# process:681 / NBPF14
# process:682 / NUDT4B
# process:683 / NOTCH2NLC
# process:684 / AC242842.3
# process:685 / NBPF19
# process:686 / H2BC18
# process:687 / H3C13
# process:688 / H3C14
# process:689 / H2AC18
# process:690 / H2AC19
# process:691 / H3C15
# process:692 / H4C15
# process:693 / H2BC21
# process:694 / H2AC20
# process:695 / BOLA1
# process:696 / SV2A
# process:697 / SF3B4
# process:698 / OTUD7B
# process:699 / PLEKHO1
# process:700 / APH1A
# process:701 / C1orf54
# process:702 / CIART
# process:703 / RPRD2
# process:704 / TARS2
# process:705 / ECM1
# process:706 / MCL1
# process:707 / GOLPH3L
# process:708 / HORMAD1
# process:709 / CTSS
# process:710 / CTSK
# process:711 / ARNT
# process:712 / CTXND2
# process:713 / CERS2
# process:714 / MINDY1
# process:715 / PRUNE1
# process:716 / BNIPL
# process:717 / C1orf56
# process:718 / GABPB2
# process:719 / SEMA6C
# process:720 / TNFAIP8L2
# process:721 / SCNM1
# process:722 / TMOD4
# process:723 / PIP5K1A
# process:724 / PSMD4
# process:725 / ZNF687
# process:726 / PI4KB
# process:727 / RFX5
# process:728 / PSMB4
# process:729 / POGZ
# process:730 / TUFT1
# process:731 / SNX27
# process:732 / CELF3
# process:733 / RIIAD1
# process:734 / OAZ3
# process:735 / TDRKH
# process:736 / RORC
# process:737 / THEM5
# process:738 / THEM4
# process:739 / TCHHL1
# process:740 / RPTN
# process:741 / HRNR
# process:742 / FLG
# process:743 / FLG2
# process:744 / LCE5A
# process:745 / CRCT1
# process:746 / LCE3E
# process:747 / LCE3D
# process:748 / LCE3C
# process:749 / LCE3B
# process:750 / LCE3A
# process:751 / LCE2D
# process:752 / LCE2A
# process:753 / LCE4A
# process:754 / C1orf68
# process:755 / LCE1F
# process:756 / LCE1E
# process:757 / LCE1C
# process:758 / LCE1B
# process:759 / LCE1A
# process:760 / LCE6A
# process:761 / AL162596.1
# process:762 / SMCP
# process:763 / SPRR5
# process:764 / SPRR1A
# process:765 / SPRR3
# process:766 / SPRR2D
# process:767 / SPRR2A
# process:768 / SPRR2B
# process:769 / SPRR2E
# process:770 / SPRR2G
# process:771 / PRR9
# process:772 / LORICRIN
# process:773 / PGLYRP3
# process:774 / PGLYRP4
# process:775 / S100A9
# process:776 / S100A8
# process:777 / S100A7A
# process:778 / S100A7L2
# process:779 / S100A7
# process:780 / S100A6
# process:781 / S100A4
# process:782 / S100A14
# process:783 / S100A1
# process:784 / SNAPIN
# process:785 / ILF2
# process:786 / INTS3
# process:787 / SLC27A3
# process:788 / GATAD2B
# process:789 / SLC39A1
# process:790 / AL358472.7
# process:791 / CREB3L4
# process:792 / JTB
# process:793 / NUP210L
# process:794 / TPM3
# process:795 / C1orf43
# process:796 / UBAP2L
# process:797 / AQP10
# process:798 / ATP8B2
# process:799 / IL6R
# process:800 / SHE
# process:801 / ADAR
# process:802 / KCNN3
# process:803 / PMVK
# process:804 / PYGO2
# process:805 / SHC1
# process:806 / CKS1B
# process:807 / LENEP
# process:808 / ZBTB7B
# process:809 / DCST2
# process:810 / ADAM15
# process:811 / EFNA4
# process:812 / AL691442.1
# process:813 / EFNA1
# process:814 / SLC50A1
# process:815 / KRTCAP2
# process:816 / AL713999.1
# process:817 / TRIM46
# process:818 / MUC1
# process:819 / CLK2
# process:820 / PKLR
# process:821 / FDPS
# process:822 / MSTO1
# process:823 / YY1AP1
# process:824 / SYT11
# process:825 / MEX3A
# process:826 / SLC25A44
# process:827 / PMF1-BGLAP
# process:828 / PMF1
# process:829 / BGLAP
# process:830 / PAQR6
# process:831 / SMG5
# process:832 / TMEM79
# process:833 / GLMP
# process:834 / CCT3
# process:835 / MEF2D
# process:836 / TTC24
# process:837 / BCAN
# process:838 / ISG20L2
# process:839 / MRPL24
# process:840 / SH2D2A
# process:841 / NTRK1
# process:842 / PEAR1
# process:843 / LRRC71
# process:844 / ETV3L
# process:845 / ETV3
# process:846 / FCRL4
# process:847 / FCRL1
# process:848 / CD5L
# process:849 / CD1C
# process:850 / CD1E
# process:851 / OR10T2
# process:852 / OR10K2
# process:853 / OR6Y1
# process:854 / OR6P1
# process:855 / SPTA1
# process:856 / OR6N1
# process:857 / OR6K6
# process:858 / IFI16
# process:859 / FCER1A
# process:860 / OR10J5
# process:861 / APCS
# process:862 / DUSP23
# process:863 / FCRL6
# process:864 / CFAP45
# process:865 / IGSF9
# process:866 / PIGM
# process:867 / KCNJ9
# process:868 / IGSF8
# process:869 / ATP1A2
# process:870 / ATP1A4
# process:871 / CASQ1
# process:872 / PEA15
# process:873 / DCAF8
# process:874 / PEX19
# process:875 / NCSTN
# process:876 / SLAMF6
# process:877 / CD84
# process:878 / CD48
# process:879 / SLAMF7
# process:880 / LY9
# process:881 / ITLN2
# process:882 / F11R
# process:883 / AL591806.2
# process:884 / TSTD1
# process:885 / USF1
# process:886 / ARHGAP30
# process:887 / NECTIN4
# process:888 / KLHDC9
# process:889 / PFDN2
# process:890 / UFC1
# process:891 / PPOX
# process:892 / B4GALT3
# process:893 / NDUFS2
# process:894 / FCER1G
# process:895 / TOMM40L
# process:896 / NR1I3
# process:897 / PCP4L1
# process:898 / MPZ
# process:899 / CFAP126
# process:900 / FCGR2A
# process:901 / HSPA6
# process:902 / FCGR3A
# process:903 / FCGR3B
# process:904 / FCGR2B
# process:905 / FCRLA
# process:906 / ATF6
# process:907 / NOS1AP
# process:908 / AL512785.2
# process:909 / SPATA46
# process:910 / UAP1
# process:911 / CCDC190
# process:912 / RGS4
# process:913 / RGS5
# process:914 / LRRC52
# process:915 / MGST3
# process:916 / ALDH9A1
# process:917 / UCK2
# process:918 / TADA1
# process:919 / ILDR2
# process:920 / MAEL
# process:921 / STYXL2
# process:922 / POU2F1
# process:923 / RCSD1
# process:924 / ADCY10
# process:925 / MPC2
# process:926 / GPR161
# process:927 / TIPRL
# process:928 / SFT2D2
# process:929 / TBX19
# process:930 / XCL1
# process:931 / NME7
# process:932 / BLZF1
# process:933 / C1orf112
# process:934 / METTL18
# process:935 / GORAB
# process:936 / MROH9
# process:937 / FMO1
# process:938 / MYOCOS
# process:939 / MYOC
# process:940 / VAMP4
# process:941 / EEF1AKNMT
# process:942 / DNM3
# process:943 / C1orf105
# process:944 / SUCO
# process:945 / TNFSF4
# process:946 / AL139142.2
# process:947 / ANKRD45
# process:948 / TEX50
# process:949 / CENPL
# process:950 / DARS2
# process:951 / SERPINC1
# process:952 / RC3H1
# process:953 / RABGAP1L
# process:954 / CACYBP
# process:955 / MRPS14
# process:956 / KIAA0040
# process:957 / PAPPA2
# process:958 / ASTN1
# process:959 / BRINP2
# process:960 / SEC16B
# process:961 / RASAL2
# process:962 / CLEC20A
# process:963 / TEX35
# process:964 / ANGPTL1
# process:965 / TOR3A
# process:966 / AXDND1
# process:967 / NPHS2
# process:968 / FAM163A
# process:969 / CEP350
# process:970 / LHX4
# process:971 / ACBD6
# process:972 / STX6
# process:973 / IER5
# process:974 / CACNA1E
# process:975 / ZNF648
# process:976 / GLUL
# process:977 / RGSL1
# process:978 / RGS16
# process:979 / DHX9
# process:980 / LAMC1
# process:981 / LAMC2
# process:982 / NMNAT2
# process:983 / NCF2
# process:984 / ARPC5
# process:985 / TSEN15
# process:986 / EDEM3
# process:987 / HMCN1
# process:988 / TPR
# process:989 / RGS21
# process:990 / RGS13
# process:991 / RPS27AP5
# process:992 / RGS2
# process:993 / CDC73
# process:994 / CFHR1
# process:995 / CFHR2
# process:996 / ASPM
# process:997 / CRB1
# process:998 / DENND1B
# process:999 / LHX9
# process:1000 / NEK7
# process:1001 / PTPRC
# process:1002 / NR5A2
# process:1003 / INAVA
# process:1004 / KIF21B
# process:1005 / CACNA1S
# process:1006 / IGFN1
# process:1007 / TNNT2
# process:1008 / PHLDA3
# process:1009 / CSRP1
# process:1010 / TIMM17A
# process:1011 / ARL8A
# process:1012 / LGR6
# process:1013 / PPP1R12B
# process:1014 / SYT2
# process:1015 / RABIF
# process:1016 / ADIPOR1
# process:1017 / TMEM183A
# process:1018 / ADORA1
# process:1019 / BTG2
# process:1020 / FMOD
# process:1021 / ATP2B4
# process:1022 / LAX1
# process:1023 / ZBED6
# process:1024 / AC114402.2
# process:1025 / SOX13
# process:1026 / GOLT1A
# process:1027 / PLEKHA6
# process:1028 / PPP1R15B
# process:1029 / PIK3C2B
# process:1030 / MDM4
# process:1031 / LRRN2
# process:1032 / NFASC
# process:1033 / TMEM81
# process:1034 / RBBP5
# process:1035 / TMCC2
# process:1036 / NUAK2
# process:1037 / CDK18
# process:1038 / ELK4
# process:1039 / NUCKS1
# process:1040 / RAB29
# process:1041 / PM20D1
# process:1042 / SLC26A9
# process:1043 / RAB7B
# process:1044 / CTSE
# process:1045 / RHEX
# process:1046 / AVPR1B
# process:1047 / SRGAP2
# process:1048 / IKBKE
# process:1049 / RASSF5
# process:1050 / DYRK3
# process:1051 / IL10
# process:1052 / IL24
# process:1053 / PIGR
# process:1054 / PFKFB2
# process:1055 / YOD1
# process:1056 / C4BPB
# process:1057 / C4BPA
# process:1058 / CD55
# process:1059 / CR2
# process:1060 / CR1
# process:1061 / CD34
# process:1062 / PLXNA2
# process:1063 / CAMK1G
# process:1064 / LAMB3
# process:1065 / HSD11B1
# process:1066 / TRAF3IP3
# process:1067 / IRF6
# process:1068 / UTP25
# process:1069 / SERTAD4
# process:1070 / KCNH1
# process:1071 / AL590132.1
# process:1072 / AC092017.2
# process:1073 / TRAF5
# process:1074 / RD3
# process:1075 / SLC30A1
# process:1076 / NEK2
# process:1077 / LPGAT1
# process:1078 / INTS7
# process:1079 / DTL
# process:1080 / PPP2R5A
# process:1081 / PACC1
# process:1082 / NENF
# process:1083 / BATF3
# process:1084 / NSL1
# process:1085 / SPATA45
# process:1086 / FLVCR1
# process:1087 / VASH2
# process:1088 / ANGEL2
# process:1089 / PROX1
# process:1090 / SMYD2
# process:1091 / CENPF
# process:1092 / KCTD3
# process:1093 / USH2A
# process:1094 / RRP15
# process:1095 / LYPLAL1
# process:1096 / SLC30A10
# process:1097 / BPNT1
# process:1098 / IARS2
# process:1099 / C1orf115
# process:1100 / MTARC2
# process:1101 / MTARC1
# process:1102 / AL445423.3
# process:1103 / HLX
# process:1104 / AIDA
# process:1105 / CCDC185
# process:1106 / CAPN8
# process:1107 / FBXO28
# process:1108 / DEGS1
# process:1109 / WDR26
# process:1110 / DNAH14
# process:1111 / LBR
# process:1112 / ENAH
# process:1113 / SRP9
# process:1114 / TMEM63A
# process:1115 / LEFTY1
# process:1116 / AL117348.2
# process:1117 / LEFTY2
# process:1118 / SDE2
# process:1119 / ACBD3
# process:1120 / MIXL1
# process:1121 / ITPKB
# process:1122 / AL391628.1
# process:1123 / PSEN2
# process:1124 / COQ8A
# process:1125 / CDC42BPA
# process:1126 / SNAP47
# process:1127 / PRSS38
# process:1128 / WNT9A
# process:1129 / WNT3A
# process:1130 / ARF1
# process:1131 / C1orf35
# process:1132 / GUK1
# process:1133 / GJC2
# process:1134 / IBA57
# process:1135 / OBSCN
# process:1136 / TRIM17
# process:1137 / H3-4
# process:1138 / H2BU1
# process:1139 / RNF187
# process:1140 / RAB4A
# process:1141 / CCSAP
# process:1142 / NUP133
# process:1143 / ABCB10
# process:1144 / TAF5L
# process:1145 / URB2
# process:1146 / GALNT2
# process:1147 / PGBD5
# process:1148 / COG2
# process:1149 / TTC13
# process:1150 / ARV1
# process:1151 / GNPAT
# process:1152 / EXOC8
# process:1153 / SPRTN
# process:1154 / EGLN1
# process:1155 / AL445524.2
# process:1156 / TSNAX
# process:1157 / TSNAX-DISC1
# process:1158 / DISC1
# process:1159 / SIPA1L2
# process:1160 / MAP10
# process:1161 / NTPCR
# process:1162 / PCNX2
# process:1163 / KCNK1
# process:1164 / IRF2BP2
# process:1165 / RBM34
# process:1166 / B3GALNT2
# process:1167 / GNG4
# process:1168 / LYST
# process:1169 / GPR137B
# process:1170 / ERO1B
# process:1171 / ACTN2
# process:1172 / MT1HL1
# process:1173 / RYR2
# process:1174 / ZP4
# process:1175 / MTRNR2L11
# process:1176 / FMN2
# process:1177 / GREM2
# process:1178 / RGS7
# process:1179 / FH
# process:1180 / KMO
# process:1181 / CHML
# process:1182 / WDR64
# process:1183 / EXO1
# process:1184 / MAP1LC3C
# process:1185 / PLD5
# process:1186 / AKT3
# process:1187 / ZBTB18
# process:1188 / C1orf100
# process:1189 / CATSPERE
# process:1190 / AL451007.3
# process:1191 / COX20
# process:1192 / HNRNPU
# process:1193 / KIF26B
# process:1194 / SMYD3
# process:1195 / TFB2M
# process:1196 / SCCPDH
# process:1197 / AHCTF1
# process:1198 / ZNF695
# process:1199 / ZNF670
# process:1200 / ZNF669
# process:1201 / ZNF124
# process:1202 / ZNF496
# process:1203 / NLRP3
# process:1204 / OR2B11
# process:1205 / GCSAML
# process:1206 / OR2G3
# process:1207 / OR14L1P
# process:1208 / OR13G1
# process:1209 / OR6F1
# process:1210 / AC118470.1
# process:1211 / OR14A2
# process:1212 / OR14K1
# process:1213 / OR14A16
# process:1214 / OR11L1
# process:1215 / OR2T8
# process:1216 / OR2AJ1
# process:1217 / OR2AK2
# process:1218 / OR2L3
# process:1219 / OR2L13
# process:1220 / OR2M5
# process:1221 / OR2M3
# process:1222 / OR2M4
# process:1223 / OR2T33
# process:1224 / OR2T12
# process:1225 / OR2M7
# process:1226 / OR2T4
# process:1227 / OR2T6
# process:1228 / OR2T10
# process:1229 / OR2T11
# process:1230 / OR2T27
# process:1231 / CR589904.2
# process:1232 / SH3BP5L
# process:1233 / PGBD2
# process:1234 / SH3YL1
# process:1235 / ALKAL2
# process:1236 / SNTG2
# process:1237 / TPO
# process:1238 / PXDN
# process:1239 / MYT1L
# process:1240 / EIPR1
# process:1241 / TRAPPC12
# process:1242 / ADI1
# process:1243 / RNASEH1
# process:1244 / RPS7
# process:1245 / ALLC
# process:1246 / DCDC2C
# process:1247 / CMPK2
# process:1248 / RSAD2
# process:1249 / RNF144A
# process:1250 / ID2
# process:1251 / ASAP2
# process:1252 / CPSF3
# process:1253 / TAF1B
# process:1254 / CYS1
# process:1255 / RRM2
# process:1256 / HPCAL1
# process:1257 / NOL10
# process:1258 / PDIA6
# process:1259 / C2orf50
# process:1260 / SLC66A3
# process:1261 / ROCK2
# process:1262 / GREB1
# process:1263 / LPIN1
# process:1264 / TRIB2
# process:1265 / LRATD1
# process:1266 / MYCN
# process:1267 / CYRIA
# process:1268 / RAD51AP2
# process:1269 / VSNL1
# process:1270 / GEN1
# process:1271 / MSGN1
# process:1272 / KCNS3
# process:1273 / TTC32
# process:1274 / LAPTM4A
# process:1275 / SDC1
# process:1276 / PUM2
# process:1277 / RHOB
# process:1278 / TDRD15
# process:1279 / ATAD2B
# process:1280 / UBXN2A
# process:1281 / MFSD2B
# process:1282 / WDCP
# process:1283 / FKBP1B
# process:1284 / SF3B6
# process:1285 / FAM228B
# process:1286 / TP53I3
# process:1287 / AC008073.3
# process:1288 / ITSN2
# process:1289 / NCOA1
# process:1290 / PTRHD1
# process:1291 / CENPO
# process:1292 / DNAJC27
# process:1293 / POMC
# process:1294 / ASXL2
# process:1295 / KIF3C
# process:1296 / GAREM2
# process:1297 / HADHA
# process:1298 / HADHB
# process:1299 / ADGRF3
# process:1300 / OTOF
# process:1301 / FAM166C
# process:1302 / DPYSL5
# process:1303 / TMEM214
# process:1304 / OST4
# process:1305 / EMILIN1
# process:1306 / KHK
# process:1307 / CGREF1
# process:1308 / ABHD1
# process:1309 / PREB
# process:1310 / TCF23
# process:1311 / CAD
# process:1312 / UCN
# process:1313 / MPV17
# process:1314 / GTF3C2
# process:1315 / EIF2B4
# process:1316 / SNX17
# process:1317 / ZNF513
# process:1318 / PPM1G
# process:1319 / NRBP1
# process:1320 / KRTCAP3
# process:1321 / GCKR
# process:1322 / ZNF512
# process:1323 / CCDC121
# process:1324 / SLC4A1AP
# process:1325 / RBKS
# process:1326 / BABAM2
# process:1327 / FOSL2
# process:1328 / PLB1
# process:1329 / WDR43
# process:1330 / TOGARAM2
# process:1331 / ALK
# process:1332 / YPEL5
# process:1333 / LBH
# process:1334 / LCLAT1
# process:1335 / CAPN13
# process:1336 / GALNT14
# process:1337 / CAPN14
# process:1338 / SRD5A2
# process:1339 / MEMO1
# process:1340 / SLC30A6
# process:1341 / BIRC6
# process:1342 / LTBP1
# process:1343 / FAM98A
# process:1344 / CRIM1
# process:1345 / FEZ2
# process:1346 / VIT
# process:1347 / STRN
# process:1348 / HEATR5B
# process:1349 / GPATCH11
# process:1350 / CEBPZOS
# process:1351 / CDC42EP3
# process:1352 / CYP1B1
# process:1353 / HNRNPLL
# process:1354 / GALM
# process:1355 / SRSF7
# process:1356 / GEMIN6
# process:1357 / DHX57
# process:1358 / MORN2
# process:1359 / ARHGEF33
# process:1360 / SOS1
# process:1361 / PKDCC
# process:1362 / COX7A2L
# process:1363 / KCNG3
# process:1364 / MTA3
# process:1365 / THADA
# process:1366 / PLEKHH2
# process:1367 / ABCG8
# process:1368 / LRPPRC
# process:1369 / AC013717.1
# process:1370 / SLC3A1
# process:1371 / SIX3
# process:1372 / SIX2
# process:1373 / PRKCE
# process:1374 / EPAS1
# process:1375 / PIGF
# process:1376 / CRIPT
# process:1377 / STPG4
# process:1378 / AC073283.3
# process:1379 / EPCAM
# process:1380 / MSH2
# process:1381 / PPP1R21
# process:1382 / GTF2A1L
# process:1383 / AC073082.1
# process:1384 / NRXN1
# process:1385 / ASB3
# process:1386 / ERLEC1
# process:1387 / ACYP2
# process:1388 / TSPYL6
# process:1389 / SPTBN1
# process:1390 / EML6
# process:1391 / RTN4
# process:1392 / CLHC1
# process:1393 / MTIF2
# process:1394 / PNPT1
# process:1395 / BCL11A
# process:1396 / PAPOLG
# process:1397 / REL
# process:1398 / PEX13
# process:1399 / C2orf74
# process:1400 / USP34
# process:1401 / XPO1
# process:1402 / CCT4
# process:1403 / OTX1
# process:1404 / MDH1
# process:1405 / UGP2
# process:1406 / PELI1
# process:1407 / LGALSL
# process:1408 / AFTPH
# process:1409 / SERTAD2
# process:1410 / CEP68
# process:1411 / RAB1A
# process:1412 / ACTR2
# process:1413 / SPRED2
# process:1414 / ETAA1
# process:1415 / C1D
# process:1416 / WDR92
# process:1417 / PROKR1
# process:1418 / ARHGAP25
# process:1419 / GKN2
# process:1420 / GKN1
# process:1421 / ANTXR1
# process:1422 / GFPT1
# process:1423 / GMCL1
# process:1424 / SNRNP27
# process:1425 / MXD1
# process:1426 / PCBP1
# process:1427 / C2orf42
# process:1428 / PCYOX1
# process:1429 / SNRPG
# process:1430 / ADD2
# process:1431 / FIGLA
# process:1432 / CLEC4F
# process:1433 / CD207
# process:1434 / ATP6V1B1
# process:1435 / AC007040.2
# process:1436 / ZNF638
# process:1437 / SPR
# process:1438 / NOTO
# process:1439 / SMYD5
# process:1440 / CCT7
# process:1441 / FBXO41
# process:1442 / EGR4
# process:1443 / ALMS1
# process:1444 / NAT8
# process:1445 / TPRKB
# process:1446 / DUSP11
# process:1447 / STAMBP
# process:1448 / ACTG2
# process:1449 / DGUOK
# process:1450 / TET3
# process:1451 / BOLA3
# process:1452 / MOB1A
# process:1453 / MTHFD2
# process:1454 / AC006030.1
# process:1455 / SLC4A5
# process:1456 / AC005041.1
# process:1457 / C2orf81
# process:1458 / WDR54
# process:1459 / RTKN
# process:1460 / INO80B-WBP1
# process:1461 / MOGS
# process:1462 / MRPL53
# process:1463 / CCDC142
# process:1464 / PCGF1
# process:1465 / TLX2
# process:1466 / DQX1
# process:1467 / AUP1
# process:1468 / HTRA2
# process:1469 / LOXL3
# process:1470 / DOK1
# process:1471 / SEMA4F
# process:1472 / HK2
# process:1473 / POLE4
# process:1474 / EVA1A
# process:1475 / GCFC2
# process:1476 / LRRTM4
# process:1477 / REG3G
# process:1478 / REG1B
# process:1479 / REG1A
# process:1480 / REG3A
# process:1481 / SUCLG1
# process:1482 / DNAH6
# process:1483 / TMSB10
# process:1484 / TGOLN2
# process:1485 / RETSAT
# process:1486 / ELMOD3
# process:1487 / CAPG
# process:1488 / SH2D6
# process:1489 / MAT2A
# process:1490 / VAMP8
# process:1491 / VAMP5
# process:1492 / RNF181
# process:1493 / TMEM150A
# process:1494 / USP39
# process:1495 / SFTPB
# process:1496 / GNLY
# process:1497 / ATOH8
# process:1498 / PTCD3
# process:1499 / IMMT
# process:1500 / CHMP3
# process:1501 / RNF103-CHMP3
# process:1502 / CD8A
# process:1503 / CD8B
# process:1504 / RGPD1
# process:1505 / PLGLB2
# process:1506 / RGPD2
# process:1507 / FABP1
# process:1508 / THNSL2
# process:1509 / FOXI3
# process:1510 / EIF2AK3
# process:1511 / AL845331.1
# process:1512 / MRPS5
# process:1513 / ZNF514
# process:1514 / AC092835.1
# process:1515 / PROM2
# process:1516 / FAHD2A
# process:1517 / TRIM43B
# process:1518 / GPAT2
# process:1519 / ADRA2B
# process:1520 / DUSP2
# process:1521 / STARD7
# process:1522 / TMEM127
# process:1523 / ITPRIPL1
# process:1524 / NCAPH
# process:1525 / NEURL3
# process:1526 / KANSL3
# process:1527 / FER1L5
# process:1528 / CNNM3
# process:1529 / SEMA4C
# process:1530 / ANKRD36
# process:1531 / ANKRD36B
# process:1532 / COX5B
# process:1533 / ZAP70
# process:1534 / TMEM131
# process:1535 / VWA3B
# process:1536 / INPP4A
# process:1537 / COA5
# process:1538 / MGAT4A
# process:1539 / CRACDL
# process:1540 / TSGA10
# process:1541 / AC079447.1
# process:1542 / C2orf15
# process:1543 / MRPL30
# process:1544 / LYG1
# process:1545 / AFF3
# process:1546 / LONRF2
# process:1547 / CHST10
# process:1548 / NMS
# process:1549 / NPAS2
# process:1550 / TBC1D8
# process:1551 / CNOT11
# process:1552 / CREG2
# process:1553 / RFX8
# process:1554 / IL1R2
# process:1555 / IL1R1
# process:1556 / IL1RL1
# process:1557 / SLC9A2
# process:1558 / MFSD9
# process:1559 / TMEM182
# process:1560 / POU3F3
# process:1561 / C2orf49
# process:1562 / FHL2
# process:1563 / NCK2
# process:1564 / ECRG4
# process:1565 / UXS1
# process:1566 / RGPD3
# process:1567 / RGPD4
# process:1568 / SLC5A7
# process:1569 / SULT1C3
# process:1570 / SULT1C2
# process:1571 / SULT1C4
# process:1572 / GCC2
# process:1573 / RANBP2
# process:1574 / CCDC138
# process:1575 / EDAR
# process:1576 / SEPTIN10
# process:1577 / SOWAHC
# process:1578 / AC013271.1
# process:1579 / MALL
# process:1580 / AC112229.3
# process:1581 / LIMS4
# process:1582 / RGPD6
# process:1583 / MERTK
# process:1584 / TMEM87B
# process:1585 / FBLN7
# process:1586 / ZC3H8
# process:1587 / ZC3H6
# process:1588 / POLR1B
# process:1589 / CHCHD5
# process:1590 / IL37
# process:1591 / IL36A
# process:1592 / IL36B
# process:1593 / IL36RN
# process:1594 / PAX8
# process:1595 / RABL2A
# process:1596 / ACTR3
# process:1597 / DPP10
# process:1598 / DDX18
# process:1599 / EN1
# process:1600 / MARCO
# process:1601 / C1QL2
# process:1602 / C2orf76
# process:1603 / DBI
# process:1604 / TMEM37
# process:1605 / SCTR
# process:1606 / CFAP221
# process:1607 / PTPN4
# process:1608 / TMEM185B
# process:1609 / INHBB
# process:1610 / TFCP2L1
# process:1611 / TSN
# process:1612 / GYPC
# process:1613 / TEX51
# process:1614 / CYP27C1
# process:1615 / PROC
# process:1616 / MYO7B
# process:1617 / LIMS2
# process:1618 / GPR17
# process:1619 / SFT2D3
# process:1620 / POLR2D
# process:1621 / AMMECR1L
# process:1622 / SAP130
# process:1623 / HS6ST1
# process:1624 / POTEF
# process:1625 / CCDC74B
# process:1626 / SMPD4
# process:1627 / MZT2B
# process:1628 / IMP4
# process:1629 / FAM168B
# process:1630 / POTEE
# process:1631 / RAB6D
# process:1632 / TUBA3D
# process:1633 / CCDC74A
# process:1634 / ANKRD30BL
# process:1635 / GPR39
# process:1636 / NCKAP5
# process:1637 / TMEM163
# process:1638 / ACMSD
# process:1639 / MAP3K19
# process:1640 / RAB3GAP1
# process:1641 / ZRANB3
# process:1642 / R3HDM1
# process:1643 / UBXN4
# process:1644 / LCT
# process:1645 / MCM6
# process:1646 / DARS1
# process:1647 / THSD7B
# process:1648 / HNMT
# process:1649 / SPOPL
# process:1650 / NXPH2
# process:1651 / ARHGAP15
# process:1652 / GTDC1
# process:1653 / ZEB2
# process:1654 / ACVR2A
# process:1655 / ORC4
# process:1656 / MBD5
# process:1657 / EPC2
# process:1658 / KIF5C
# process:1659 / LYPD6B
# process:1660 / MMADHC
# process:1661 / RND3
# process:1662 / RBM43
# process:1663 / RIF1
# process:1664 / AC068547.1
# process:1665 / CACNB4
# process:1666 / FMNL2
# process:1667 / PRPF40A
# process:1668 / RPRM
# process:1669 / KCNJ3
# process:1670 / GPD2
# process:1671 / GALNT5
# process:1672 / CYTIP
# process:1673 / ACVR1
# process:1674 / CCDC148
# process:1675 / DAPL1
# process:1676 / TANC1
# process:1677 / WDSUB1
# process:1678 / CD302
# process:1679 / LY75-CD302
# process:1680 / ITGB6
# process:1681 / RBMS1
# process:1682 / TANK
# process:1683 / TBR1
# process:1684 / DPP4
# process:1685 / IFIH1
# process:1686 / GCA
# process:1687 / KCNH7
# process:1688 / FIGN
# process:1689 / COBLL1
# process:1690 / SLC38A11
# process:1691 / SCN3A
# process:1692 / CSRNP3
# process:1693 / SCN7A
# process:1694 / XIRP2
# process:1695 / B3GALT1
# process:1696 / NOSTRIN
# process:1697 / SPC25
# process:1698 / G6PC2
# process:1699 / DHRS9
# process:1700 / LRP2
# process:1701 / AC093899.2
# process:1702 / FASTKD1
# process:1703 / PPIG
# process:1704 / PHOSPHO2
# process:1705 / SSB
# process:1706 / MYO3B
# process:1707 / ERICH2
# process:1708 / GORASP2
# process:1709 / TLK1
# process:1710 / METTL8
# process:1711 / CYBRD1
# process:1712 / DYNC1I2
# process:1713 / METAP1D
# process:1714 / DLX1
# process:1715 / DLX2
# process:1716 / PDK1
# process:1717 / RAPGEF4
# process:1718 / MAP3K20
# process:1719 / SP3
# process:1720 / OLA1
# process:1721 / SP9
# process:1722 / SCRN3
# process:1723 / GPR155
# process:1724 / WIPF1
# process:1725 / CHRNA1
# process:1726 / LNPK
# process:1727 / HOXD13
# process:1728 / HOXD12
# process:1729 / HOXD9
# process:1730 / HOXD8
# process:1731 / HNRNPA3
# process:1732 / NFE2L2
# process:1733 / TTC30B
# process:1734 / TTC30A
# process:1735 / PDE11A
# process:1736 / RBM45
# process:1737 / OSBPL6
# process:1738 / PJVK
# process:1739 / FKBP7
# process:1740 / CCDC141
# process:1741 / SESTD1
# process:1742 / ZNF385B
# process:1743 / CWC22
# process:1744 / UBE2E3
# process:1745 / NEUROD1
# process:1746 / FRZB
# process:1747 / NCKAP1
# process:1748 / ZC3H15
# process:1749 / ITGAV
# process:1750 / CALCRL
# process:1751 / GULP1
# process:1752 / COL3A1
# process:1753 / WDR75
# process:1754 / ASNSD1
# process:1755 / ANKAR
# process:1756 / ORMDL1
# process:1757 / MFSD6
# process:1758 / NAB1
# process:1759 / GLS
# process:1760 / STAT1
# process:1761 / MYO1B
# process:1762 / NABP1
# process:1763 / CAVIN2
# process:1764 / DNAH7
# process:1765 / CCDC150
# process:1766 / C2orf66
# process:1767 / PGAP1
# process:1768 / HSPE1
# process:1769 / HSPE1-MOB4
# process:1770 / MOB4
# process:1771 / FTCDNL1
# process:1772 / TYW5
# process:1773 / MAIP1
# process:1774 / AOX1
# process:1775 / BZW1
# process:1776 / CLK1
# process:1777 / PPIL3
# process:1778 / NIF3L1
# process:1779 / ORC2
# process:1780 / CFLAR
# process:1781 / CASP8
# process:1782 / STRADB
# process:1783 / C2CD6
# process:1784 / TMEM237
# process:1785 / MPP4
# process:1786 / KIAA2012
# process:1787 / NOP58
# process:1788 / BMPR2
# process:1789 / ICA1L
# process:1790 / WDR12
# process:1791 / NBEAL1
# process:1792 / CYP20A1
# process:1793 / ABI2
# process:1794 / CD28
# process:1795 / ICOS
# process:1796 / PARD3B
# process:1797 / INO80D
# process:1798 / NDUFS1
# process:1799 / EEF1B2
# process:1800 / GPR1
# process:1801 / ZDBF2
# process:1802 / ADAM23
# process:1803 / FAM237A
# process:1804 / DYTN
# process:1805 / MDH1B
# process:1806 / FASTKD2
# process:1807 / CPO
# process:1808 / KLF7
# process:1809 / CREB1
# process:1810 / PLEKHM3
# process:1811 / CRYGD
# process:1812 / CRYGB
# process:1813 / C2orf80
# process:1814 / IDH1
# process:1815 / PTH2R
# process:1816 / MAP2
# process:1817 / UNC80
# process:1818 / RPE
# process:1819 / ACADL
# process:1820 / CPS1
# process:1821 / ERBB4
# process:1822 / SPAG16
# process:1823 / VWC2L
# process:1824 / ABCA12
# process:1825 / ATIC
# process:1826 / FN1
# process:1827 / MREG
# process:1828 / MARCHF4
# process:1829 / SMARCAL1
# process:1830 / RPL37A
# process:1831 / IGFBP5
# process:1832 / TNP1
# process:1833 / TNS1
# process:1834 / RUFY4
# process:1835 / TMBIM1
# process:1836 / SLC11A1
# process:1837 / VIL1
# process:1838 / USP37
# process:1839 / CNOT9
# process:1840 / BCS1L
# process:1841 / STK36
# process:1842 / TTLL4
# process:1843 / CYP27A1
# process:1844 / PRKAG3
# process:1845 / WNT6
# process:1846 / CDK5R2
# process:1847 / CFAP65
# process:1848 / IHH
# process:1849 / AC068946.1
# process:1850 / SLC23A3
# process:1851 / CNPPD1
# process:1852 / ZFAND2B
# process:1853 / ABCB6
# process:1854 / ATG9A
# process:1855 / ANKZF1
# process:1856 / STK16
# process:1857 / DNAJB2
# process:1858 / DNPEP
# process:1859 / DES
# process:1860 / AC053503.6
# process:1861 / SPEGNB
# process:1862 / GMPPA
# process:1863 / CHPF
# process:1864 / OBSL1
# process:1865 / INHA
# process:1866 / STK11IP
# process:1867 / SLC4A3
# process:1868 / PAX3
# process:1869 / AC010980.1
# process:1870 / SGPP2
# process:1871 / MOGAT1
# process:1872 / ACSL3
# process:1873 / KCNE4
# process:1874 / SCG2
# process:1875 / AP1S3
# process:1876 / MRPL44
# process:1877 / SERPINE2
# process:1878 / FAM124B
# process:1879 / CUL3
# process:1880 / CCDC195
# process:1881 / DOCK10
# process:1882 / IRS1
# process:1883 / COL4A3
# process:1884 / MFF
# process:1885 / TM4SF20
# process:1886 / AGFG1
# process:1887 / SCYGR2
# process:1888 / SCYGR7
# process:1889 / CCL20
# process:1890 / DAW1
# process:1891 / SPHKAP
# process:1892 / TRIP12
# process:1893 / FBXO36
# process:1894 / SLC16A14
# process:1895 / SP140
# process:1896 / SP140L
# process:1897 / SP100
# process:1898 / ITM2C
# process:1899 / SPATA3
# process:1900 / C2orf72
# process:1901 / HTR2B
# process:1902 / ARMC9
# process:1903 / B3GNT7
# process:1904 / TEX44
# process:1905 / PTMA
# process:1906 / PDE6D
# process:1907 / COPS7B
# process:1908 / NPPC
# process:1909 / DIS3L2
# process:1910 / ALPP
# process:1911 / ALPG
# process:1912 / ALPI
# process:1913 / PRSS56
# process:1914 / CHRND
# process:1915 / CHRNG
# process:1916 / EIF4E2
# process:1917 / EFHD1
# process:1918 / GIGYF2
# process:1919 / KCNJ13
# process:1920 / NEU2
# process:1921 / ATG16L1
# process:1922 / DGKD
# process:1923 / USP40
# process:1924 / UGT1A8
# process:1925 / UGT1A10
# process:1926 / UGT1A7
# process:1927 / UGT1A3
# process:1928 / UGT1A1
# process:1929 / MROH2A
# process:1930 / HJURP
# process:1931 / TRPM8
# process:1932 / SH3BP4
# process:1933 / ACKR3
# process:1934 / COPS8
# process:1935 / COL6A3
# process:1936 / MLPH
# process:1937 / PRLH
# process:1938 / LRRFIP1
# process:1939 / RBM44
# process:1940 / UBE2F
# process:1941 / SCLY
# process:1942 / KLHL30
# process:1943 / ERFE
# process:1944 / ILKAP
# process:1945 / HES6
# process:1946 / TRAF3IP1
# process:1947 / ASB1
# process:1948 / TWIST2
# process:1949 / HDAC4
# process:1950 / NDUFA10
# process:1951 / OR6B3
# process:1952 / OTOS
# process:1953 / GPC1
# process:1954 / ANKMY1
# process:1955 / CAPN10
# process:1956 / AQP12B
# process:1957 / AQP12A
# process:1958 / AGXT
# process:1959 / MAB21L4
# process:1960 / CROCC2
# process:1961 / PASK
# process:1962 / PPP1R7
# process:1963 / ANO7
# process:1964 / SEPTIN2
# process:1965 / STK25
# process:1966 / BOK
# process:1967 / ATG4B
# process:1968 / GAL3ST2
# process:1969 / CNTN6
# process:1970 / CRBN
# process:1971 / SUMF1
# process:1972 / SETMAR
# process:1973 / ITPR1
# process:1974 / ARL8B
# process:1975 / EDEM1
# process:1976 / GRM7
# process:1977 / CAV3
# process:1978 / SRGAP3
# process:1979 / LHFPL4
# process:1980 / MTMR14
# process:1981 / CPNE9
# process:1982 / OGG1
# process:1983 / CAMK1
# process:1984 / ARPC4
# process:1985 / TTLL3
# process:1986 / RPUSD3
# process:1987 / CIDEC
# process:1988 / JAGN1
# process:1989 / IL17RC
# process:1990 / CRELD1
# process:1991 / PRRT3
# process:1992 / EMC3
# process:1993 / FANCD2
# process:1994 / VHL
# process:1995 / TATDN2
# process:1996 / AC022384.1
# process:1997 / GHRL
# process:1998 / ATP2B2
# process:1999 / SLC6A11
# process:2000 / SLC6A1
# process:2001 / HRH1
# process:2002 / ATG7
# process:2003 / VGLL4
# process:2004 / TAMM41
# process:2005 / SYN2
# process:2006 / TIMP4
# process:2007 / TSEN2
# process:2008 / MKRN2OS
# process:2009 / MKRN2
# process:2010 / RAF1
# process:2011 / TMEM40
# process:2012 / RPL32
# process:2013 / IQSEC1
# process:2014 / WNT7A
# process:2015 / CHCHD4
# process:2016 / AC090004.1
# process:2017 / LSM3
# process:2018 / SLC6A6
# process:2019 / C3orf20
# process:2020 / RBSN
# process:2021 / SH3BP5
# process:2022 / HACL1
# process:2023 / ANKRD28
# process:2024 / GALNT15
# process:2025 / DPH3
# process:2026 / OXNAD1
# process:2027 / DAZL
# process:2028 / PLCL2
# process:2029 / SATB1
# process:2030 / KCNH8
# process:2031 / EFHB
# process:2032 / RAB5A
# process:2033 / PP2D1
# process:2034 / SGO1
# process:2035 / ZNF385D
# process:2036 / UBE2E2
# process:2037 / UBE2E1
# process:2038 / NKIRAS1
# process:2039 / RPL15
# process:2040 / NR1D2
# process:2041 / THRB
# process:2042 / RARB
# process:2043 / TOP2B
# process:2044 / LRRC3B
# process:2045 / NEK10
# process:2046 / SLC4A7
# process:2047 / EOMES
# process:2048 / AZI2
# process:2049 / ZCWPW2
# process:2050 / AC098650.1
# process:2051 / RBMS3
# process:2052 / GADL1
# process:2053 / OSBPL10
# process:2054 / CMTM7
# process:2055 / CMTM6
# process:2056 / DYNC1LI1
# process:2057 / TRIM71
# process:2058 / CCR4
# process:2059 / GLB1
# process:2060 / TMPPE
# process:2061 / FBXL2
# process:2062 / UBP1
# process:2063 / CLASP2
# process:2064 / ARPP21
# process:2065 / STAC
# process:2066 / DCLK3
# process:2067 / LRRFIP2
# process:2068 / GOLGA4
# process:2069 / CTDSPL
# process:2070 / DLEC1
# process:2071 / ACAA1
# process:2072 / OXSR1
# process:2073 / SLC22A13
# process:2074 / SLC22A14
# process:2075 / EXOG
# process:2076 / SCN10A
# process:2077 / GORASP1
# process:2078 / TTC21A
# process:2079 / CSRNP1
# process:2080 / XIRP1
# process:2081 / RPSA
# process:2082 / MYRIP
# process:2083 / EIF1B
# process:2084 / ENTPD3
# process:2085 / CTNNB1
# process:2086 / VIPR1
# process:2087 / SEC22C
# process:2088 / SS18L2
# process:2089 / NKTR
# process:2090 / ZBTB47
# process:2091 / KLHL40
# process:2092 / HHATL
# process:2093 / CCDC13
# process:2094 / ZNF662
# process:2095 / POMGNT2
# process:2096 / ANO10
# process:2097 / ABHD5
# process:2098 / TCAIM
# process:2099 / ZNF445
# process:2100 / ZNF852
# process:2101 / ZKSCAN7
# process:2102 / ZNF197
# process:2103 / ZNF502
# process:2104 / ZNF501
# process:2105 / KIAA1143
# process:2106 / KIF15
# process:2107 / TMEM42
# process:2108 / TGM4
# process:2109 / ZDHHC3
# process:2110 / EXOSC7
# process:2111 / CDCP1
# process:2112 / LARS2
# process:2113 / LIMD1
# process:2114 / SACM1L
# process:2115 / SLC6A20
# process:2116 / CCR9
# process:2117 / CXCR6
# process:2118 / CCR3
# process:2119 / CCR1
# process:2120 / CCRL2
# process:2121 / RTP3
# process:2122 / LRRC2
# process:2123 / AC104304.2
# process:2124 / FAM240A
# process:2125 / ALS2CL
# process:2126 / TMIE
# process:2127 / PRSS50
# process:2128 / MYL3
# process:2129 / PTH1R
# process:2130 / NBEAL2
# process:2131 / SETD2
# process:2132 / KLHL18
# process:2133 / SCAP
# process:2134 / SMARCC1
# process:2135 / DHX30
# process:2136 / CDC25A
# process:2137 / CAMP
# process:2138 / ZNF589
# process:2139 / NME6
# process:2140 / SPINK8
# process:2141 / FBXW12
# process:2142 / ATRIP
# process:2143 / TREX1
# process:2144 / SHISA5
# process:2145 / PFKFB4
# process:2146 / COL7A1
# process:2147 / TMEM89
# process:2148 / CELSR3
# process:2149 / NCKIPSD
# process:2150 / IP6K2
# process:2151 / SLC25A20
# process:2152 / P4HTM
# process:2153 / WDR6
# process:2154 / DALRD3
# process:2155 / NDUFAF3
# process:2156 / IMPDH2
# process:2157 / QRICH1
# process:2158 / QARS1
# process:2159 / USP19
# process:2160 / KLHDC8B
# process:2161 / C3orf84
# process:2162 / IHO1
# process:2163 / C3orf62
# process:2164 / USP4
# process:2165 / TCTA
# process:2166 / AMT
# process:2167 / APEH
# process:2168 / MST1
# process:2169 / RNF123
# process:2170 / UBA7
# process:2171 / TRAIP
# process:2172 / CAMKV
# process:2173 / SEMA3F
# process:2174 / GNAT1
# process:2175 / SLC38A3
# process:2176 / GNAI2
# process:2177 / SEMA3B
# process:2178 / LSMEM2
# process:2179 / IFRD2
# process:2180 / NAA80
# process:2181 / HYAL1
# process:2182 / HYAL2
# process:2183 / TUSC2
# process:2184 / RASSF1
# process:2185 / NPRL2
# process:2186 / Z84492.1
# process:2187 / TMEM115
# process:2188 / CACNA2D2
# process:2189 / CISH
# process:2190 / MAPKAPK3
# process:2191 / DOCK3
# process:2192 / DCAF1
# process:2193 / RAD54L2
# process:2194 / IQCF6
# process:2195 / AC097636.1
# process:2196 / IQCF5
# process:2197 / IQCF1
# process:2198 / PCBP4
# process:2199 / ABHD14B
# process:2200 / ABHD14A
# process:2201 / RPL29
# process:2202 / DUSP7
# process:2203 / POC1A
# process:2204 / ALAS1
# process:2205 / TLR9
# process:2206 / AC097637.1
# process:2207 / TWF2
# process:2208 / PPM1M
# process:2209 / WDR82
# process:2210 / GLYCTK
# process:2211 / DNAH1
# process:2212 / PHF7
# process:2213 / SEMA3G
# process:2214 / NISCH
# process:2215 / NT5DC2
# process:2216 / SMIM4
# process:2217 / PBRM1
# process:2218 / GNL3
# process:2219 / GLT8D1
# process:2220 / ITIH1
# process:2221 / ITIH3
# process:2222 / ITIH4
# process:2223 / MUSTN1
# process:2224 / STIMATE-MUSTN1
# process:2225 / SFMBT1
# process:2226 / AC096887.1
# process:2227 / RFT1
# process:2228 / DCP1A
# process:2229 / CACNA1D
# process:2230 / CHDH
# process:2231 / IL17RB
# process:2232 / ACTR8
# process:2233 / SELENOK
# process:2234 / CACNA2D3
# process:2235 / WNT5A
# process:2236 / ERC2
# process:2237 / CCDC66
# process:2238 / TASOR
# process:2239 / SPATA12
# process:2240 / IL17RD
# process:2241 / HESX1
# process:2242 / APPL1
# process:2243 / ASB14
# process:2244 / PDE12
# process:2245 / ARF4
# process:2246 / ABHD6
# process:2247 / RPP14
# process:2248 / PXK
# process:2249 / PDHB
# process:2250 / KCTD6
# process:2251 / FAM3D
# process:2252 / CFAP20DC
# process:2253 / FHIT
# process:2254 / PTPRG
# process:2255 / C3orf14
# process:2256 / SYNPR
# process:2257 / C3orf49
# process:2258 / THOC7
# process:2259 / ATXN7
# process:2260 / MAGI1
# process:2261 / LRIG1
# process:2262 / SUCLG2
# process:2263 / TAFA1
# process:2264 / TMF1
# process:2265 / UBA3
# process:2266 / LMOD3
# process:2267 / FRMD4B
# process:2268 / MITF
# process:2269 / FOXP1
# process:2270 / AC097634.4
# process:2271 / EIF4E3
# process:2272 / RYBP
# process:2273 / SHQ1
# process:2274 / GXYLT2
# process:2275 / PDZRN3
# process:2276 / CNTN3
# process:2277 / FRG2C
# process:2278 / ZNF717
# process:2279 / ROBO2
# process:2280 / ROBO1
# process:2281 / GBE1
# process:2282 / VGLL3
# process:2283 / POU1F1
# ...
# process:11359 / CD37
# process:11360 / TEAD2
# process:11361 / KASH5
# process:11362 / PIH1D1
# process:11363 / ALDH16A1
# process:11364 / AC010619.1
# process:11365 / RPL13A
# process:11366 / RPS11
# process:11367 / RCN3
# process:11368 / NOSIP
# process:11369 / SCAF1
# process:11370 / BCL2L12
# process:11371 / PRMT1
# process:11372 / ADM5
# process:11373 / TSKS
# process:11374 / AP2A1
# process:11375 / MED25
# process:11376 / PTOV1
# process:11377 / PNKP
# process:11378 / IL4I1
# process:11379 / NUP62
# process:11380 / AC011452.1
# process:11381 / ATF5
# process:11382 / SIGLEC11
# process:11383 / VRK3
# process:11384 / ZNF473
# process:11385 / IZUMO2
# process:11386 / NAPSA
# process:11387 / POLD1
# process:11388 / AC020909.1
# process:11389 / SPIB
# process:11390 / MYBPC2
# process:11391 / FAM71E1
# process:11392 / JOSD2
# process:11393 / LRRC4B
# process:11394 / SYT3
# process:11395 / C19orf81
# process:11396 / SHANK1
# process:11397 / CLEC11A
# process:11398 / AC010325.1
# process:11399 / KLK1
# process:11400 / KLK15
# process:11401 / KLK3
# process:11402 / KLK2
# process:11403 / KLK5
# process:11404 / KLK7
# process:11405 / KLK8
# process:11406 / KLK9
# process:11407 / KLK10
# process:11408 / KLK12
# process:11409 / KLK13
# process:11410 / SIGLEC9
# process:11411 / CD33
# process:11412 / IGLON5
# process:11413 / VSIG10L
# process:11414 / ETFB
# process:11415 / AC008750.7
# process:11416 / CLDND2
# process:11417 / NKG7
# process:11418 / C19orf84
# process:11419 / SIGLEC10
# process:11420 / SIGLEC12
# process:11421 / ZNF175
# process:11422 / SPACA6
# process:11423 / HAS1
# process:11424 / FPR1
# process:11425 / FPR2
# process:11426 / FPR3
# process:11427 / ZNF649
# process:11428 / ZNF350
# process:11429 / ZNF615
# process:11430 / ZNF432
# process:11431 / ZNF841
# process:11432 / ZNF616
# process:11433 / ZNF836
# process:11434 / PPP2R1A
# process:11435 / ZNF766
# process:11436 / ZNF480
# process:11437 / ZNF610
# process:11438 / ZNF880
# process:11439 / ZNF528
# process:11440 / ZNF534
# process:11441 / ZNF578
# process:11442 / ZNF808
# process:11443 / ZNF701
# process:11444 / ZNF83
# process:11445 / AC022150.4
# process:11446 / ZNF28
# process:11447 / ZNF468
# process:11448 / ZNF320
# process:11449 / ZNF888
# process:11450 / ZNF816-ZNF321P
# process:11451 / ZNF816
# process:11452 / ZNF160
# process:11453 / ZNF347
# process:11454 / ZNF665
# process:11455 / ZNF845
# process:11456 / ZNF525
# process:11457 / ZNF761
# process:11458 / ZNF813
# process:11459 / ZNF331
# process:11460 / DPRX
# process:11461 / PRKCG
# process:11462 / CACNG7
# process:11463 / CACNG6
# process:11464 / VSTM1
# process:11465 / TARM1
# process:11466 / TFPT
# process:11467 / LENG1
# process:11468 / TMC4
# process:11469 / TSEN34
# process:11470 / RPS9
# process:11471 / LILRB3
# process:11472 / LILRB5
# process:11473 / LILRB2
# process:11474 / TTYH1
# process:11475 / LENG8
# process:11476 / LENG9
# process:11477 / LAIR2
# process:11478 / LILRA1
# process:11479 / LILRB1
# process:11480 / LILRB4
# process:11481 / KIR3DL3
# process:11482 / KIR2DL3
# process:11483 / KIR2DL1
# process:11484 / KIR2DL4
# process:11485 / FCAR
# process:11486 / NLRP2
# process:11487 / EPS8L1
# process:11488 / TNNT1
# process:11489 / DNAAF3
# process:11490 / TMEM86B
# process:11491 / PPP6R1
# process:11492 / HSPBP1
# process:11493 / TMEM150B
# process:11494 / KMT5C
# process:11495 / AC020922.1
# process:11496 / FAM71E2
# process:11497 / IL11
# process:11498 / TMEM190
# process:11499 / RPL28
# process:11500 / UBE2S
# process:11501 / ISOC2
# process:11502 / C19orf85
# process:11503 / SSC5D
# process:11504 / SBK2
# process:11505 / ZNF579
# process:11506 / FIZ1
# process:11507 / ZNF524
# process:11508 / ZNF580
# process:11509 / EPN1
# process:11510 / RFPL4A
# process:11511 / NLRP4
# process:11512 / NLRP13
# process:11513 / NLRP8
# process:11514 / ZNF787
# process:11515 / ZSCAN5B
# process:11516 / ZSCAN5C
# process:11517 / ZSCAN5A
# process:11518 / ZNF582
# process:11519 / ZNF583
# process:11520 / ZNF667
# process:11521 / ZFP28
# process:11522 / ZNF470
# process:11523 / ZNF835
# process:11524 / PEG3
# process:11525 / ZIM3
# process:11526 / ZNF460
# process:11527 / ZNF543
# process:11528 / TRAPPC2B
# process:11529 / AC003002.1
# process:11530 / ZNF548
# process:11531 / AC003002.3
# process:11532 / AC003002.2
# process:11533 / ZNF17
# process:11534 / ZNF749
# process:11535 / VN1R1
# process:11536 / ZNF772
# process:11537 / ZNF419
# process:11538 / ZNF773
# process:11539 / ZNF549
# process:11540 / ZNF530
# process:11541 / ZNF211
# process:11542 / ZSCAN4
# process:11543 / ZNF551
# process:11544 / AC003006.1
# process:11545 / ZNF154
# process:11546 / ZNF671
# process:11547 / ZNF586
# process:11548 / ZNF552
# process:11549 / ZNF587B
# process:11550 / ZNF814
# process:11551 / ZNF587
# process:11552 / AC010326.2
# process:11553 / ZNF417
# process:11554 / ZNF256
# process:11555 / ZNF135
# process:11556 / ZSCAN18
# process:11557 / ZNF329
# process:11558 / ZNF274
# process:11559 / ZNF544
# process:11560 / ZNF8
# process:11561 / ZSCAN22
# process:11562 / A1BG
# process:11563 / ZNF837
# process:11564 / RPS5
# process:11565 / ZNF584
# process:11566 / ZNF132
# process:11567 / ZNF324B
# process:11568 / ZNF324
# process:11569 / ZNF446
# process:11570 / SLC27A5
# process:11571 / ZBTB45
# process:11572 / TRIM28
# process:11573 / CHMP2A
# process:11574 / UBE2M
# process:11575 / SRY
# process:11576 / RPS4Y1
# process:11577 / TGIF2LY
# process:11578 / PCDH11Y
# process:11579 / TSPY2
# process:11580 / TBL1Y
# process:11581 / TSPY3
# process:11582 / TSPY9P
# process:11583 / DDX3Y
# process:11584 / VCY
# process:11585 / VCY1B
# process:11586 / CDY2A
# process:11587 / EIF1AY
# process:11588 / RBMY1B
# process:11589 / RBMY1D
# process:11590 / PRY2
# process:11591 / RBMY1F
# process:11592 / RBMY1J
# process:11593 / PRY
# process:11594 / BPY2
# process:11595 / CDY1B
# process:11596 / BPY2B
# process:11597 / DAZ3
# process:11598 / DAZ4
# process:11599 / OR11H1
# process:11600 / POTEH
# process:11601 / XKR3
# process:11602 / GAB4
# process:11603 / IL17RA
# process:11604 / TMEM121B
# process:11605 / HDHD5
# process:11606 / SLC25A18
# process:11607 / MICAL3
# process:11608 / TUBA8
# process:11609 / USP18
# process:11610 / GGTLC3
# process:11611 / TMEM191B
# process:11612 / RIMBP3
# process:11613 / DGCR6
# process:11614 / DGCR2
# process:11615 / GSC2
# process:11616 / HIRA
# process:11617 / MRPL40
# process:11618 / UFD1
# process:11619 / CDC45
# process:11620 / CLDN5
# process:11621 / SEPTIN5
# process:11622 / TBX1
# process:11623 / GNB1L
# process:11624 / COMT
# process:11625 / ARVCF
# process:11626 / TRMT2A
# process:11627 / RANBP1
# process:11628 / RTN4R
# process:11629 / ZNF74
# process:11630 / SCARF2
# process:11631 / AC007731.4
# process:11632 / KLHL22
# process:11633 / MED15
# process:11634 / PI4KA
# process:11635 / SERPIND1
# process:11636 / SNAP29
# process:11637 / AIFM3
# process:11638 / SLC7A4
# process:11639 / GGT2
# process:11640 / FAM246A
# process:11641 / RIMBP3B
# process:11642 / TMEM191C
# process:11643 / RIMBP3C
# process:11644 / UBE2L3
# process:11645 / YDJC
# process:11646 / CCDC116
# process:11647 / PPIL2
# process:11648 / MAPK1
# process:11649 / PPM1F
# process:11650 / VPREB1
# process:11651 / ZNF280B
# process:11652 / IGLL5
# process:11653 / RSPH14
# process:11654 / GNAZ
# process:11655 / BCR
# process:11656 / IGLL1
# process:11657 / DRICH1
# process:11658 / RGL4
# process:11659 / C22orf15
# process:11660 / CHCHD10
# process:11661 / SMARCB1
# process:11662 / DERL3
# process:11663 / AP000350.4
# process:11664 / MIF
# process:11665 / AC253536.7
# process:11666 / GSTT4
# process:11667 / CABIN1
# process:11668 / SUSD2
# process:11669 / GGT5
# process:11670 / SPECC1L
# process:11671 / ADORA2A
# process:11672 / UPB1
# process:11673 / GUCD1
# process:11674 / SNRPD3
# process:11675 / LRRC75B
# process:11676 / GGT1
# process:11677 / PIWIL3
# process:11678 / TMEM211
# process:11679 / CRYBB3
# process:11680 / CRYBB2
# process:11681 / GRK3
# process:11682 / MYO18B
# process:11683 / ASPHD2
# process:11684 / HPS4
# process:11685 / SRRD
# process:11686 / TFIP11
# process:11687 / CRYBB1
# process:11688 / MN1
# process:11689 / PITPNB
# process:11690 / TTC28
# process:11691 / CHEK2
# process:11692 / HSCB
# process:11693 / CCDC117
# process:11694 / XBP1
# process:11695 / ZNRF3
# process:11696 / C22orf31
# process:11697 / KREMEN1
# process:11698 / EWSR1
# process:11699 / RASL10A
# process:11700 / AP1B1
# process:11701 / RFPL1
# process:11702 / NEFH
# process:11703 / THOC5
# process:11704 / NIPSNAP1
# process:11705 / ZMAT5
# process:11706 / HORMAD2
# process:11707 / LIF
# process:11708 / OSM
# process:11709 / CASTOR1
# process:11710 / TBC1D10A
# process:11711 / MTFP1
# process:11712 / SEC14L4
# process:11713 / SEC14L6
# process:11714 / PES1
# process:11715 / TCN2
# process:11716 / DUSP18
# process:11717 / OSBP2
# process:11718 / MORC2
# process:11719 / TUG1
# process:11720 / SELENOM
# process:11721 / PLA2G3
# process:11722 / RNF185
# process:11723 / PIK3IP1
# process:11724 / PATZ1
# process:11725 / EIF4ENIF1
# process:11726 / SFI1
# process:11727 / PISD
# process:11728 / DEPDC5
# process:11729 / SLC5A1
# process:11730 / C22orf42
# process:11731 / SLC5A4
# process:11732 / RTCB
# process:11733 / BPIFC
# process:11734 / FBXO7
# process:11735 / SYN3
# process:11736 / TIMP3
# process:11737 / HMGXB4
# process:11738 / HMOX1
# process:11739 / MB
# process:11740 / APOL6
# process:11741 / RBFOX2
# process:11742 / APOL3
# process:11743 / APOL4
# process:11744 / APOL2
# process:11745 / APOL1
# process:11746 / MYH9
# process:11747 / FOXRED2
# process:11748 / CACNG2
# process:11749 / IFT27
# process:11750 / PVALB
# process:11751 / NCF4
# process:11752 / CSF2RB
# process:11753 / MPST
# process:11754 / KCTD17
# process:11755 / IL2RB
# process:11756 / C1QTNF6
# process:11757 / RAC2
# process:11758 / CYTH4
# process:11759 / ELFN2
# process:11760 / CARD10
# process:11761 / CDC42EP1
# process:11762 / LGALS2
# process:11763 / SH3BP1
# process:11764 / Z83844.2
# process:11765 / PDXP
# process:11766 / TRIOBP
# process:11767 / H1-0
# process:11768 / GCAT
# process:11769 / MICALL1
# process:11770 / C22orf23
# process:11771 / SOX10
# process:11772 / PICK1
# process:11773 / SLC16A8
# process:11774 / PLA2G6
# process:11775 / TMEM184B
# process:11776 / CSNK1E
# process:11777 / TPTEP2-CSNK1E
# process:11778 / KCNJ4
# process:11779 / KDELR3
# process:11780 / DDX17
# process:11781 / FAM227A
# process:11782 / CBY1
# process:11783 / GTPBP1
# process:11784 / SUN2
# process:11785 / DNAL4
# process:11786 / CBX6
# process:11787 / APOBEC3A
# process:11788 / APOBEC3B
# process:11789 / AL022318.4
# process:11790 / APOBEC3D
# process:11791 / APOBEC3F
# process:11792 / APOBEC3G
# process:11793 / APOBEC3H
# process:11794 / CBX7
# process:11795 / PDGFB
# process:11796 / SYNGR1
# process:11797 / MGAT3
# process:11798 / MIEF1
# process:11799 / ATF4
# process:11800 / RPS19BP1
# process:11801 / ENTHD1
# process:11802 / GRAP2
# process:11803 / Z82206.1
# process:11804 / TNRC6B
# process:11805 / AL022238.3
# process:11806 / SGSM3
# process:11807 / SLC25A17
# process:11808 / ST13
# process:11809 / XPNPEP3
# process:11810 / DNAJB7
# process:11811 / RBX1
# process:11812 / EP300
# process:11813 / L3MBTL2
# process:11814 / CHADL
# process:11815 / ZC3H7B
# process:11816 / TEF
# process:11817 / ACO2
# process:11818 / PHF5A
# process:11819 / POLR3H
# process:11820 / DESI1
# process:11821 / XRCC6
# process:11822 / SNU13
# process:11823 / MEI1
# process:11824 / SHISA8
# process:11825 / LINC00634
# process:11826 / SEPTIN3
# process:11827 / WBP2NL
# process:11828 / NAGA
# process:11829 / PHETA2
# process:11830 / SMDT1
# process:11831 / CYP2D6
# process:11832 / TCF20
# process:11833 / SERHL2
# process:11834 / A4GALT
# process:11835 / ARFGAP3
# process:11836 / PACSIN2
# process:11837 / BIK
# process:11838 / MCAT
# process:11839 / TSPO
# process:11840 / TTLL12
# process:11841 / SCUBE1
# process:11842 / MPPED1
# process:11843 / EFCAB6
# process:11844 / SULT4A1
# process:11845 / PNPLA5
# process:11846 / PNPLA3
# process:11847 / SAMM50
# process:11848 / PARVG
# process:11849 / SHISAL1
# process:11850 / RTL6
# process:11851 / PRR5-ARHGAP8
# process:11852 / UPK3A
# process:11853 / FAM118A
# process:11854 / SMC1B
# process:11855 / FBLN1
# process:11856 / ATXN10
# process:11857 / WNT7B
# process:11858 / PPARA
# process:11859 / CDPF1
# process:11860 / GTSE1
# process:11861 / TRMU
# process:11862 / CELSR1
# process:11863 / BRD1
# process:11864 / ZBED4
# process:11865 / TTLL8
# process:11866 / MLC1
# process:11867 / SELENOO
# process:11868 / TUBGCP6
# process:11869 / HDAC10
# process:11870 / DENND6B
# process:11871 / MIOX
# process:11872 / LMF2
# process:11873 / SCO2
# process:11874 / TYMP
# process:11875 / KLHDC7B
# process:11876 / SYCE3
# process:11877 / ARSA
# process:11878 / SHANK3
# process:11879 / FP565260.2
# process:11880 / CU639417.1
# process:11881 / SIK1B
# process:11882 / CBSL
# process:11883 / U2AF1L5
# process:11884 / CRYAA2
# process:11885 / SMIM11B
# process:11886 / SMIM34B
# process:11887 / SAMSN1
# process:11888 / NRIP1
# process:11889 / USP25
# process:11890 / BTG3
# process:11891 / C21orf91
# process:11892 / TMPRSS15
# process:11893 / ATP5PF
# process:11894 / GABPA
# process:11895 / CYYR1
# process:11896 / ADAMTS1
# process:11897 / ADAMTS5
# process:11898 / CCT8
# process:11899 / MAP3K7CL
# process:11900 / CLDN17
# process:11901 / CLDN8
# process:11902 / KRTAP24-1
# process:11903 / KRTAP25-1
# process:11904 / KRTAP26-1
# process:11905 / KRTAP27-1
# process:11906 / KRTAP23-1
# process:11907 / KRTAP13-3
# process:11908 / KRTAP13-4
# process:11909 / KRTAP19-1
# process:11910 / KRTAP19-2
# process:11911 / KRTAP19-4
# process:11912 / KRTAP19-6
# process:11913 / KRTAP6-3
# process:11914 / KRTAP6-2
# process:11915 / KRTAP22-1
# process:11916 / KRTAP6-1
# process:11917 / KRTAP20-1
# process:11918 / KRTAP20-2
# process:11919 / KRTAP20-3
# process:11920 / KRTAP21-3
# process:11921 / KRTAP21-2
# process:11922 / KRTAP21-1
# process:11923 / KRTAP11-1
# process:11924 / SOD1
# process:11925 / SCAF4
# process:11926 / MIS18A
# process:11927 / URB1
# process:11928 / PAXBP1
# process:11929 / C21orf62
# process:11930 / OLIG2
# process:11931 / OLIG1
# process:11932 / IL10RB
# process:11933 / IFNAR1
# process:11934 / IFNGR2
# process:11935 / TMEM50B
# process:11936 / DNAJC28
# process:11937 / GART
# process:11938 / SON
# process:11939 / DONSON
# process:11940 / AP000311.1
# process:11941 / ITSN1
# process:11942 / ATP5PO
# process:11943 / MRPS6
# process:11944 / SLC5A3
# process:11945 / SMIM11A
# process:11946 / FAM243A
# process:11947 / SMIM34A
# process:11948 / RCAN1
# process:11949 / CLIC6
# process:11950 / RUNX1
# process:11951 / SETD4
# process:11952 / CBR1
# process:11953 / CBR3
# process:11954 / DOP1B
# process:11955 / MORC3
# process:11956 / SIM2
# process:11957 / HLCS
# process:11958 / RIPPLY3
# process:11959 / TTC3
# process:11960 / VPS26C
# process:11961 / KCNJ15
# process:11962 / ETS2
# process:11963 / HMGN1
# process:11964 / GET1-SH3BGR
# process:11965 / LCA5L
# process:11966 / SH3BGR
# process:11967 / IGSF5
# process:11968 / DSCAM
# process:11969 / BACE2
# process:11970 / FAM3B
# process:11971 / MX1
# process:11972 / RIPK4
# process:11973 / PRDM15
# process:11974 / C2CD2
# process:11975 / ZBTB21
# process:11976 / UMODL1
# process:11977 / ABCG1
# process:11978 / TFF3
# process:11979 / TFF2
# process:11980 / TFF1
# process:11981 / TMPRSS3
# process:11982 / UBASH3A
# process:11983 / RSPH1
# process:11984 / SLC37A1
# process:11985 / WDR4
# process:11986 / NDUFV3
# process:11987 / ERVH48-1
# process:11988 / PKNOX1
# process:11989 / CBS
# process:11990 / CRYAA
# process:11991 / HSF2BP
# process:11992 / H2BS1
# process:11993 / RRP1B
# process:11994 / CSTB
# process:11995 / RRP1
# process:11996 / AP001054.1
# process:11997 / TRAPPC10
# process:11998 / PWP2
# process:11999 / ICOSLG
# process:12000 / DNMT3L
# process:12001 / CFAP410
# process:12002 / TRPM2
# process:12003 / LRRC3
# process:12004 / KRTAP10-1
# process:12005 / KRTAP10-6
# process:12006 / KRTAP10-7
# process:12007 / KRTAP10-8
# process:12008 / KRTAP10-9
# process:12009 / KRTAP10-11
# process:12010 / KRTAP12-4
# process:12011 / KRTAP12-3
# process:12012 / KRTAP12-1
# process:12013 / KRTAP10-12
# process:12014 / UBE2G2
# process:12015 / SUMO3
# process:12016 / ITGB2
# process:12017 / POFUT2
# process:12018 / SLC19A1
# process:12019 / PCBP3
# process:12020 / COL6A2
# process:12021 / FTCD
# process:12022 / SPATC1L
# process:12023 / YBEY
# process:12024 / C21orf58
# process:12025 / AP000471.1
# process:12026 / DIP2A
# process:12027 / S100B
# process:12028 / PRMT2
# process:12029 / MT-ND1
# process:12030 / MT-ND2
# process:12031 / MT-CO2
# process:12032 / MT-ATP8
# process:12033 / MT-ATP6
# process:12034 / MT-ND3
# process:12035 / MT-ND4L
# process:12036 / MT-ND5
# process:12037 / MT-CYB
# process:12038 / Unnamed: 0
# process:12039 / OR4F5
#    feature_name  kl_divergence
# 0          GYPE       5.867323
# 1         ADRB2       5.825714
# 2          CD5L       5.746667
# 3        ANGPT4       5.723198
# 4         GPM6A       5.692274
# ..          ...            ...
# 79        EPAS1       3.036145
# 80        ADRB1       3.013379
# 81     ARHGEF15       3.011971
# 82        ACTN2       3.004149
# 83     ARHGAP31       3.003712
#
# [84 rows x 2 columns]

# %%
# Filtering the choosed 134 features from the original dataset
index_columns = np.append(choosed_features['feature_name'].values, ['label'])
df_choosed = df[index_columns]
df_choosed.to_csv('TCGA_Labeled_GOA_KL.csv')

df_choosed.columns
# Out:
# Index(['GYPE', 'ADRB2', 'CD5L', 'ANGPT4', 'GPM6A', 'NCKAP5', 'CD300LG', 'SGCG',
#        'SH3GL3', 'CA4', 'CAVIN2', 'RTKN2', 'HBM', 'ACADL', 'TEK', 'AGER',
#        'WNT3A', 'MYZAP', 'ITLN2', 'FHL5', 'ST8SIA6', 'LGI3', 'CCM2L', 'BTNL9',
#        'ADH1B', 'FHL1', 'PTPN21', 'EMP2', 'CNTN6', 'CLDN18', 'HSPA12B',
#        'LIMS2', 'SPOCK2', 'EMCN', 'S1PR1', 'STXBP6', 'FABP4', 'SOX7', 'VEGFD',
#        'RXFP1', 'SFTPC', 'ACVRL1', 'SLC39A8', 'LDB2', 'OTC', 'CALCRL', 'KANK3',
#        'RAMP3', 'SIRPB1', 'JPH4', 'SLC6A4', 'RS1', 'MGAT3', 'TAL1', 'ALKAL2',
#        'LRRC36', 'GRIA1', 'SCUBE1', 'ANGPTL7', 'GRK5', 'VEPH1', 'PRKG2',
#        'ANOS1', 'PRX', 'FAM110D', 'EFCC1', 'TENT5B', 'DPEP2', 'LAMP3',
#        'TMEM100', 'SEMA3G', 'CLEC1A', 'CCDC141', 'SSMEM1', 'ABCA8', 'DKK2',
#        'SLC4A1', 'CAV2', 'GIMAP8', 'EPAS1', 'ADRB1', 'ARHGEF15', 'ACTN2',
#        'ARHGAP31', 'label'],
#       dtype='object')
